# %% [raw]
# ---
# author: Fabrizio Damicelli
# badges: true
# categories:
# - Python
# - Filesystem
# comments: false
# date: '2026-05-27'
# title: '`watchfiles`: A handy Python library to watch for file changes'
# description: A pythonic alternative to register and react to filesystem notifications
# filters:
# - social-share
# output-file: watchfiles.html
# share:
#   description: '""'
#   linkedin: true
#   mastodon: true
#   permalink: '"https://fabridamicelli.github.io/posts/watchfiles.html"'
#   reddit: true
#   twitter: true
# toc: true
#
# ---

# %% [markdown]
# Operating systems provide APIs that allow programs to be notified about changes in the filesystem, such as when files are created, modified, deleted, or renamed.
# Programs can register interest in those events, similar to subscribing to a topic, and react when they occur, for example by running code.
#
# In Python you can do that using the [`watchfiles`](https://github.com/samuelcolvin/watchfiles) library (which is indeed a wrapper around the Rust [`notify-rs`](https://docs.rs/notify/latest/notify/) crate, so it is fast!).
#
# The basic usage is pretty straight forward – and elegant:

# %% [markdown]
# ```python
# from watchfiles import watch
#
# for changes in watch('./path/to/dir'):
#     print(changes)
#     # Do anything here
# ```

# %% [markdown]
# That's basically an infinite loop hooked to the notifications.
#
# You can access the `changes` set of tuples that look like this:
#
# ```python
# {(<Change.added: 1>, '/path/to/the/added/file')}
# {(<Change.modified: 2>, '/path/to/the/modified/file')}
# {(<Change.deleted: 3>, '/path/to/the/deleted/file')}
# ```

# %% [markdown]
# <div style="text-align: right; font-size: 40px; font-family: 'Inconsolata', monospace;">
#   /Fin
# </div>
#
# <div style="font-family: 'Inconsolata', monospace;">
# Any bugs, questions, comments, suggestions? Ping me on [twitter](https://www.twitter.com/fabridamicelli) or drop me an e-mail (fabridamicelli at gmail).
# Share this article on your favourite platform:
# </div>
