# %% [raw]
# ---
# aliases:
# - /til/2024-05-19-bigqueryrc.html
# author: Fabrizio Damicelli
# badges: true
# categories:
# - python
# comments: false
# date: '2024-05-19'
# description: ''
# filters:
# - social-share
# output-file: bigqueryrc.html
# share:
#   description: '"Use .bigqueryrc to set BigQuery global configuration. "'
#   linkedin: true
#   mastodon: true
#   permalink: '"https://fabridamicelli.github.io/posts/bigqueryrc.html"'
#   reddit: true
#   twitter: true
# title: Use .bigqueryrc to set BigQuery global configuration
# toc: true
#
# ---

# %% [markdown]
# I started using the nice vim plugin [vim-dadbod](https://github.com/tpope/vim-dadbod) which allows to fire database queries and see the output *inside* vim/neovim.
#
# While setting it up to work with [BigQuery](https://cloud.google.com/bigquery?hl=en) I ran into the error coming from the fact that BigQuery's format to name a table has changed in time and `bq` uses the old one (legacy) as default.
# The legacy format reads:
# `project:dataset.table` (notice `:`) while the newer format goes by: `project.dataset.table` (with `.` instead).
#
# It turns out there is a file called `.bigqueryrc` where you can set a global configuration and tell `bq` (the command line tool to interact with BigQuery in the terminal) to use the newer format by setting the flag `use_legacy_sql=false`:
#
# ```toml
# credential_file = /path/to/some/file.json
# project_id = name-of-your-default-project
#
# [query]
# use_legacy_sql = false
# ```

# %% [markdown]
# The CLI-tool `bq` also accepts the file as optional argument so you can pass custom config for a query.
# If you run `bq --help` you'll see:
#
# ```bash
#   --bigqueryrc: Path to configuration file. The configuration file specifies new
#     defaults for any flags, and can be overrridden by specifying the flag on the
#     command line. If the --bigqueryrc flag is not specified, the BIGQUERYRC
#     environment variable is used. If that is not specified, the path
#     "~/.bigqueryrc" is used.
#     (default: '~/.bigqueryrc')
#
# ```
#
# Read more about that in the [official documetation](https://cloud.google.com/bigquery/docs/reference/bq-cli-reference?hl=en).

# %% [markdown]
# <div style="text-align: right; font-size: 40px; font-family: 'Inconsolata', monospace;">
#   /Fin
# </div>
#
# <div style="font-family: 'Inconsolata', monospace;">
# Any bugs, questions, comments, suggestions? Ping me on [twitter](https://www.twitter.com/fabridamicelli) or drop me an e-mail (fabridamicelli at gmail).
# Share this article on your favourite platform:
# </div>
